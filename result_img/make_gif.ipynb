# %%
from PIL import Image, ImageDraw
import os
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
files = os.listdir('.')

# %%
file20 =  [x for x in files if x[0] == "2"]
print(file20[21])
file20.remove("20_result_id11391.png")
file20.remove("20_result_id8613.png")
file20.remove("20_result_id18114.png")
file20.remove("20_result_id14268.png")
file20.remove("20_result_id16441.png")
file20.remove("20_result_id23144.png")
file20.remove("20_result_id21318.png")
file20.remove("20_result_id31740.png")
file20.remove("20_result_id10092.png")
file20.remove("20_result_id31336.png")
file20.remove("20_result_id33096.png")
file20.remove("20_result_id10382.png")
file20.remove("20_result_id20855.png")
file20.remove("20_result_id33396.png")
file20.remove("20_result_id18777.png")
file20.remove("20_result_id13771.png")
file20.remove("20_result_id8232.png")
file20.remove("20_result_id22969.png")
file20.remove("20_result_id12638.png")
file20.remove("20_result_id15145.png")
file20.remove("20_result_id4365.png")
file20.remove("20_result_id22827.png")
file20.remove("20_result_id17806.png")
file20.remove("20_result_id31535.png")
file20.remove("20_result_id25240.png")
file20.remove("20_result_id9159.png")
file20.remove("20_result_id10258.png")
file20.remove("20_result_id20424.png")
file20.remove("20_result_id18627.png")
file20.remove("20_result_id20115.png")
file20.remove("20_result_id23486.png")
file20.remove("20_result_id27820.png")
file20.remove("20_result_id10860.png")
file20.remove("20_result_id15433.png")
file20.remove("20_result_id15499.png")
file20.remove("20_result_id8724.png")
file20.remove("20_result_id33637.png")
file20.remove("20_result_id23703.png")
file20.remove("20_result_id21393.png")
file20.remove("20_result_id18576.png")
file20.remove("20_result_id24756.png")
file20.remove("20_result_id18096.png")



print(len(file20))
# Out:
# 20_result_id13289.png
# 58

# %%
# file20

# %%
Image.open('20_result_id18576.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1137x241 at 0x7FCF0A8668D0>

# %%
Image.open(file20[16]).size[0]
# Out:
# 1137

# %%
imgs = []
for file in file20[:]:
    img = Image.open(file).resize((1137,250))
#     print(file)
#     plt.figure()
#     plt.imshow(img)
    imgs.append(img)

# %%
import random
random.shuffle(imgs)
len(imgs)
# Out:
# 58

# %%
duration = 2000
imgs[0].save('retrieval{}.gif'.format(str(duration)),save_all=True,append_images=imgs,duration=duration,loop=0)
