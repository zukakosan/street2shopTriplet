# %% [markdown]
# # TopKの遷移を一つのグラフにまとめます
# - 各モデルで出力したtxtから読み込む

# %%
import matplotlib.pyplot as plt
import pickle
import numpy as np

# %%
category = 'T_Shirt'

# %%
f = open('./pickle/{}/test_pairs.pickle'.format(category),'rb')
test_pairs = pickle.load(f)

# %%
f = open('./model/T_Shirt/Single/a0.1/512/TopK_99.txt','rb')
single_model = pickle.load(f)

# %%
f = open('./model/T_Shirt//TripletLoss_512.txt','rb')
dualNormal_model = pickle.load(f)

# %%
f = open('./model/T_Shirt/improved_tripletloss/a0.1b0.05/300/topK_vals.txt','rb')
dualImproved_model = pickle.load(f)

# %%
f = open('./model/T_Shirt/Single/a0.1b0.05/512/TopK_99.txt','rb')
singleImproved_model = pickle.load(f)

# %%
x = list(range(1,51))
chancelv=np.array(x)/len(test_pairs)
plt.plot(x,single_model,c='b',label='Single_M0.1D512({})'.format(round(single_model[19],3)))
plt.plot(x,dualNormal_model,c='r',label='Dual_M0.1D512({})'.format(round(dualNormal_model[19],3)))
plt.plot(x,dualImproved_model,c='g',label='DualImp_M0.1_M0.05_D300({})'.format(round(dualImproved_model[19],3)))
plt.plot(x,singleImproved_model[:50],c='m',label='SingleImp_M0.1_M0.05_D300({})'.format(round(singleImproved_model[19],3)))

# plt.plot(x,topk_vals,c='r',marker='o',label='improvedTripletLoss({})'.format(round(topk_vals[4],3)))
plt.plot(x,chancelv,linestyle='dashed',label='chance level(0.00984)')

# graph settings
plt.legend(loc='best')#,bbox_to_anchor=(1, 0.2))
plt.grid('True')
plt.title("top-k accuracy")
plt.xlabel("k-value")
plt.ylabel("top-k acc")

plt.savefig('./compare_topK.png',dpi=300)
# Out:
# /home/pip/koki_ishizuka/.conda/envs/py35-zukapy/lib/python3.5/site-packages/matplotlib/cbook/deprecation.py:107: MatplotlibDeprecationWarning: Passing one of 'on', 'true', 'off', 'false' as a boolean is deprecated; use an actual boolean (True/False) instead.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %%
print(dualNormal_model)
# Out:
# [0.025590551181102362, 0.05561023622047244, 0.08415354330708662, 0.1062992125984252, 0.12598425196850394, 0.13976377952755906, 0.15255905511811024, 0.16781496062992127, 0.18208661417322836, 0.18996062992125984, 0.19783464566929135]

# %%
x = list(range(1,51))
chancelv=np.array(x)/len(test_pairs)
plt.plot(x,single_model,c='b',label='Single({})'.format(round(single_model[19],3)))
plt.plot(x,singleImproved_model[:50],c='m',label='SingleImprove({})'.format(round(singleImproved_model[19],3)))

plt.plot(x,dualNormal_model,c='r',label='Dual({})'.format(round(dualNormal_model[19],3)))
plt.plot(x,dualImproved_model,c='g',label='DualImprove({})'.format(round(dualImproved_model[19],3)))

# plt.plot(x,topk_vals,c='r',marker='o',label='improvedTripletLoss({})'.format(round(topk_vals[4],3)))
plt.plot(x,chancelv,linestyle='dashed',label='chance level(0.00984)')

# graph settings
plt.legend(loc='best')#,bbox_to_anchor=(1, 0.2))
plt.grid('True')
plt.title("top-k accuracy")
plt.xlabel("k-value")
plt.ylabel("top-k acc")

plt.savefig('./img_retrieval/compare_topK.png',dpi=300)
# Out:
# /home/pip/koki_ishizuka/.conda/envs/py35-zukapy/lib/python3.5/site-packages/matplotlib/cbook/deprecation.py:107: MatplotlibDeprecationWarning: Passing one of 'on', 'true', 'off', 'false' as a boolean is deprecated; use an actual boolean (True/False) instead.
#   warnings.warn(message, mplDeprecation, stacklevel=1)
