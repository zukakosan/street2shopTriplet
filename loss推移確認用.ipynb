# %% [markdown]
# # pickle保存したlossの推移を確認する

# %%
import numpy as np
import pickle
import matplotlib.pyplot as plt
import os

# %%
f = open('./model/Dress/Single_normal/a0.1/512/history99.txt','rb')
snhist = pickle.load(f)

# %%
f = open('./model/Dress/Single_improved/a0.1b0.05/512/history99.txt','rb')
sihist = pickle.load(f)

# %%
f = open('./model/Dress/Dual_normal/a0.1/512/history99.txt','rb')
dnhist = pickle.load(f)

# %%
f = open('./model/Dress/Dual_improved/a0.1b0.05/300/history99.txt','rb')
dihist = pickle.load(f)

# %%
def make_losshist(hist):
    loss_hist = []
    for h in hist:
        loss_hist.append(np.float(h['loss'][0]))
    return loss_hist

# %%
x = list(range(1,101))

plt.plot(x,make_losshist(snhist),c='b',linestyle='solid',label='Single')
plt.plot(x,make_losshist(sihist),c='m',linestyle='dashed',label='SingleImprove')
plt.plot(x,make_losshist(dnhist),c='r',linestyle='dotted',label='Dual')
plt.plot(x,make_losshist(dihist),c='g',linestyle='dashdot',label='DualImprove')

plt.grid('True')
plt.title("")
plt.xlabel("epoch")
plt.ylabel("Improved Triplet Loss/Triplet loss")
plt.legend(loc='best')#,bbox_to_anchor=(1, 0.2))
plt.savefig('./img_analysis/losshist.png',dpi=300)
plt.show()
# Out:
# /opt/anaconda3/envs/zukapy35/lib/python3.5/site-packages/matplotlib/cbook/deprecation.py:107: MatplotlibDeprecationWarning: Passing one of 'on', 'true', 'off', 'false' as a boolean is deprecated; use an actual boolean (True/False) instead.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %%
plt.plot(x,make_losshist(snhist),c='r',label='Dual_D300M0.1_0.05')
plt.legend(loc='best')#,bbox_to_anchor=(1, 0.2))
plt.grid('True')
plt.title("")
plt.xlabel("epoch")
plt.ylabel("Improved Triplet loss")
# plt.savefig('./img_analysis/lossD300M01005.png',dpi=300)
plt.show()
# Out:
# /home/pip/koki_ishizuka/.conda/envs/py35-zukapy/lib/python3.5/site-packages/matplotlib/cbook/deprecation.py:107: MatplotlibDeprecationWarning: Passing one of 'on', 'true', 'off', 'false' as a boolean is deprecated; use an actual boolean (True/False) instead.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %% [markdown]
# ## その他作業用パート

# %%
12359+1758
# Out:
# 14117

# %%
import os
len(os.listdir('./dataset/crop_img/img/DRESSES/Dress/'))
# Out:
# 2662

# %%
ids = os.listdir('./dataset/crop_img/img/DRESSES/Dress/')
length = 0
for id_ in ids:
    length += len(os.listdir('./dataset/crop_img/img/DRESSES/Dress/'+id_))
length
# Out:
# 18658

# %%
import numpy as np
np.random.randint(0)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-ad22401f3c6d> in <module>()
#       1 import numpy as np
# ----> 2 np.random.randint(0)
#
# mtrand.pyx in mtrand.RandomState.randint()
#
# ValueError: low >= high

# %%
ids = os.listdir('./dataset/crop_img/img/CLOTHING/Pants/')
len(ids)
# Out:
# 597
